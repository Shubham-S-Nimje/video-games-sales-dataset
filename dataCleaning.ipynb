# %% [markdown]
# ### 📊 Data Processing & Analysis Overview
#
# #### 🐼 **Pandas**
#
# Widely used for **data wrangling** and **data manipulation** tasks such as:
#
# * Removing duplicates
# * Fixing missing/null values (e.g., `Region`, `NA_Sales`)
# * Renaming columns for consistency
# * Handling outliers (e.g., `Global_Sales`)
# * Standardizing categorical values (e.g., formatting `Country` names consistently)
#
# #### 🔢 **NumPy**
#
# A core library for **numerical computing** in Python, used for:
#
# * Performing mathematical operations
# * Creating and manipulating arrays
# * Implementing linear algebra routines
#
# ---
#
# ### 📈 Visualization Tasks
#
# * **Bar Chart**: Display **National Sales by Region and Country**
# * **Box Plot**: Visualize the distribution of **Global Sales by Platform**
#
# ---

# %%
import numpy as np 
import pandas as pd

data = pd.read_csv(r'D:\Learning\numpy\Video Games\VideoGamesSales.csv')
data.shape
# Out:
# (5909, 15)

# %%
data.head(2)
# Out:
#    Rank               Name Platform  Year Month     Genre Publisher  \
# 0     1         Wii Sports      Wii  2010   Jan    Sports  Nintendo
# 1     2  Super Mario Bros.      NES  2010   Feb  Platform  Nintendo
#
#          Country       City       State Region NA_Sales  Global_Sales  \
# 0  United States  Fairfield  California   West   $41.49         82.74
# 1  United States    Edmonds  Washington   West   $29.08         40.24
#
#    NA_Profit  Global_Profit
# 0     12.447         24.822
# 1      8.724         12.072

# %%
data[data.duplicated()].shape # Check for duplicates
# Out:
# (16, 15)

# %%
data.drop_duplicates(inplace=True) # Remove duplicates

# %%
data[data.duplicated()].shape # Check for duplicates
# Out:
# (0, 15)

# %%
data.isnull().sum() # Check for null values
# Out:
# Rank              0
# Name              0
# Platform          0
# Year              0
# Month             0
# Genre             0
# Publisher        12
# Country           0
# City              0
# State             0
# Region           27
# NA_Sales          0
# Global_Sales      0
# NA_Profit         0
# Global_Profit     0
# dtype: int64

# %%
# data[data['Publisher'].isnull()]
data['Publisher'].isnull().sum() # Check for null values in 'Publisher' column
# Out:
# np.int64(12)

# %%
data['Publisher'].fillna('Unknown', inplace=True) # Fill null values in 'Publisher' with 'Unknown'
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11996\2227881935.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Publisher'].fillna('Unknown', inplace=True) # Fill null values in 'Publisher' with 'Unknown'

# %%
data['Publisher'].isnull().sum()
# Out:
# np.int64(0)

# %%
data.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year              0
# Month             0
# Genre             0
# Publisher         0
# Country           0
# City              0
# State             0
# Region           27
# NA_Sales          0
# Global_Sales      0
# NA_Profit         0
# Global_Profit     0
# dtype: int64

# %%
data['Region'].isnull().sum()
# Out:
# np.int64(27)

# %%
data['Region'].fillna('North', inplace=True) # Fill null values in 'Region' with 0
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11996\2490411421.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Region'].fillna('North', inplace=True) # Fill null values in 'Region' with 0

# %%
data.isnull().sum()
# Out:
# Rank             0
# Name             0
# Platform         0
# Year             0
# Month            0
# Genre            0
# Publisher        0
# Country          0
# City             0
# State            0
# Region           0
# NA_Sales         0
# Global_Sales     0
# NA_Profit        0
# Global_Profit    0
# dtype: int64

# %%
data['NA_Sales'].replace('[$]', '', regex=True, inplace=True) # Remove $ sign from 'NA_Sales'
data
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11996\1057091554.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['NA_Sales'].replace('[$]', '', regex=True, inplace=True) # Remove $ sign from 'NA_Sales'
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# ...

# %%
pd.to_numeric(data['NA_Sales'], errors='coerce') # Convert 'Global_Sales' to numeric, coercing errors
# Out:
# 0       41.49
# 1       29.08
# 2       15.85
# 3       15.75
# 4       11.27
#         ...
# 5904     0.21
# 5905     0.15
# 5906     0.24
# 5907     0.17
# 5908     0.00
# Name: NA_Sales, Length: 5893, dtype: float64

# %%
# Ensure NA_Sales is numeric before calculating mean
data['NA_Sales'] = pd.to_numeric(data['NA_Sales'], errors='coerce')
avaraege_sales = data['NA_Sales'].mean() # Calculate average sales
int(avaraege_sales)
# Out:
# 0

# %%
data['NA_Sales'] = data['NA_Sales'].fillna(avaraege_sales) # Fill null values in 'NA_Sales' with average sales
data
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# 3        4                          Wii Sports Resort      Wii  2010   Apr
# 4        5                   Pokemon Red/Pokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#              Genre           Publisher        Country        City  \
# ...

# %%
data['Country'] = data['Country'].str.replace('United States', 'USA') # Replace 'United States' with 'USA'
data
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# 3        4                          Wii Sports Resort      Wii  2010   Apr
# 4        5                   Pokemon Red/Pokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#              Genre           Publisher    Country        City  \
# ...

# %%
data[data['Country'] == 'USA'].shape # Check how many rows have 'Country' as 'USA'
# Out:
# (2785, 15)

# %%
data.rename(columns={'NA_Sales': 'National Sales', 'Global_Sales': 'Global Sales'}, inplace=True) # Rename columns
data
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# 3        4                          Wii Sports Resort      Wii  2010   Apr
# 4        5                   Pokemon Red/Pokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#              Genre           Publisher    Country        City  \
# ...

# %%
data.rename(columns={'NA_Profit': 'National Profit', 'Global_Profit': 'Global Profit'}, inplace=True) # Rename columns
data
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# 3        4                          Wii Sports Resort      Wii  2010   Apr
# 4        5                   Pokemon Red/Pokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#              Genre           Publisher    Country        City  \
# ...

# %%
sales_cap = data['National Sales'].quantile(0.95) # Calculate 95th percentile for 'National Sales'
int(sales_cap)
# Out:
# 2

# %%
data['National Sales'] = np.where(data['National Sales'] > sales_cap, sales_cap, data['National Sales']) # Cap 'National Sales' at 95th percentile
data
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# 3        4                          Wii Sports Resort      Wii  2010   Apr
# 4        5                   Pokemon Red/Pokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#              Genre           Publisher    Country        City  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.head(2)
# Out:
#    Rank               Name Platform  Year Month     Genre Publisher Country  \
# 0     1         Wii Sports      Wii  2010   Jan    Sports  Nintendo     USA
# 1     2  Super Mario Bros.      NES  2010   Feb  Platform  Nintendo     USA
#
#         City       State Region  National Sales  Global Sales  \
# 0  Fairfield  California   West            2.07         82.74
# 1    Edmonds  Washington   West            2.07         40.24
#
#    National Profit  Global Profit
# 0           12.447         24.822
# 1            8.724         12.072

# %%
pd.to_numeric(data['National Sales'], errors='coerce')
# Out:
# 0       2.07
# 1       2.07
# 2       2.07
# 3       2.07
# 4       2.07
#         ...
# 5904    0.21
# 5905    0.15
# 5906    0.24
# 5907    0.17
# 5908    0.00
# Name: National Sales, Length: 5893, dtype: float64

# %% [markdown]
# ### Create bar chart

# %%
National_Sales = data.groupby(['Region','Country'])['National Sales'].sum().reset_index().sort_values(by='National Sales', ascending=True)
National_Sales
# Out:
#     Region    Country  National Sales
# 1     East  Australia            1.35
# 3    North  Australia           15.24
# 6    South  Australia           16.30
# 4    North        USA           17.69
# 5    Other  Australia           28.21
# 7    South        USA          405.99
# 0  Central        USA          558.67
# 2     East        USA          668.92
# 8     West  Australia          683.62
# 9     West        USA          796.65

# %%
plt.figure(figsize=(16, 8))
sns.barplot(x='Region', y='National Sales', data=National_Sales, hue='Country')

plt.title('National Sales by Region and Country', fontweight='bold', fontsize=16)
plt.xlabel('Region', fontweight='bold', fontsize=16)
plt.ylabel('National Sales', fontweight='bold', fontsize=16)    
plt.show()

# %% [markdown]
# ### Create bax chart

# %%
data.head(2)
# Out:
#    Rank               Name Platform  Year Month     Genre Publisher Country  \
# 0     1         Wii Sports      Wii  2010   Jan    Sports  Nintendo     USA
# 1     2  Super Mario Bros.      NES  2010   Feb  Platform  Nintendo     USA
#
#         City       State Region  National Sales  Global Sales  \
# 0  Fairfield  California   West            2.07         82.74
# 1    Edmonds  Washington   West            2.07         40.24
#
#    National Profit  Global Profit
# 0           12.447         24.822
# 1            8.724         12.072

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Country', y='National Sales', data=data, showmeans=True, hue='Genre', meanprops={"marker":"o", "markerfacecolor":"white", "markeredgecolor":"green", "markersize":"10"}) 
plt.title('National Sales Distribution by Region and Country', fontweight='bold', fontsize=16)
plt.xlabel('Region', fontweight='bold', fontsize=16)    
plt.ylabel('National Sales', fontweight='bold', fontsize=16)
plt.legend(title='Country', loc='upper right')
plt.show()

# %%
data.head(2)
# Out:
#    Rank               Name Platform  Year Month     Genre Publisher Country  \
# 0     1         Wii Sports      Wii  2010   Jan    Sports  Nintendo     USA
# 1     2  Super Mario Bros.      NES  2010   Feb  Platform  Nintendo     USA
#
#         City       State Region  National Sales  Global Sales  \
# 0  Fairfield  California   West            2.07         82.74
# 1    Edmonds  Washington   West            2.07         40.24
#
#    National Profit  Global Profit
# 0           12.447         24.822
# 1            8.724         12.072

# %% [markdown]
# ### Create pie chart

# %%
Sales = data.groupby(['Country'])[['National Sales', 'Global Sales']].sum().reset_index()
Country = Sales['Country']
National_Sales = Sales['National Sales']
Global_Sales = Sales['Global Sales']

fig, axs = plt.subplots(1, 2, figsize=(10, 7))

axs[0].pie(National_Sales, labels=Country, autopct='%1.1f%%', startangle=90)
axs[0].set_title('National Sales by Country', fontweight='bold', fontsize=16)

axs[1].pie(Global_Sales, labels=Country, autopct='%1.1f%%', startangle=90)
axs[1].set_title('Global Sales by Country', fontweight='bold', fontsize=16)

plt.show()

# %% [markdown]
# ### Create line chart

# %%
#create a line chart 
plt.figure(figsize=(10, 6))

#Line chart for National Sales
plt.plot(data['Year'], data['National Sales'], marker='o', linestyle='-', color='b', label='National Sales')

#Line chart for Global Sales
plt.plot(data['Year'], data['Global Sales'], marker='s', linestyle='--', color='g', label='Global Sales')

#adding title and labels
plt.title('National Sales and Global Sales Over Years', fontweight='bold', fontsize=16)
plt.xlabel('Year', fontweight='bold', fontsize=16)
plt.ylabel('Sales', fontweight='bold', fontsize=16)
plt.legend()

# Display the line chart
plt.grid(True)
plt.show()
